# %%
#import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt

# %%
iris=pd.read_csv("iris.csv")
data = pd.DataFrame(iris)

# %%
#Task 1: Load the iris_dataset in your program in a python dataframe. View the First 5 row items of that dataframe. 

df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  Calyx Width
# 0           5.1          3.5           1.4          0.2  setosa            1
# 1           4.9          3.0           1.4          0.2  setosa            0
# 2           4.7          3.2           1.3          0.2  setosa            0
# 3           4.6          3.1           1.5          0.2  setosa            0
# 4           5.0          3.6           1.4          0.2  setosa            1

# %%
#Task 1: Load the iris_dataset in your program in a python dataframe. 
#View the First 3 row items of that dataframe. 

df.tail(3)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      Calyx Width
# 147            1
# 148            1
# 149            1

# %%
#Task 2: Show the data items in a sorted manner, sorted by 'Petal Length'
df.sort_values('petal_length')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 22            4.6          3.6           1.0          0.2     setosa
# 13            4.3          3.0           1.1          0.1     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 35            5.0          3.2           1.2          0.2     setosa
# 36            5.5          3.5           1.3          0.2     setosa
# 40            5.0          3.5           1.3          0.3     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# 16            5.4          3.9           1.3          0.4     setosa
# 17            5.1          3.5           1.4          0.3     setosa
# 45            4.8          3.0           1.4          0.3     setosa
# ...

# %%
##Task 3: Group data items by Species Name
#calculate the mean for each of the 4 columns for each group
#save them in a new dataframe and print

df.groupby('species')['sepal_length','sepal_width','petal_length','petal_width'].mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.418         1.464        0.244
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
#Task 4.1: Plot Sepal_length VS Sepal_width in a Scatter Plot, Petal_length VS Petal_width in another scatter plot
#Use subplot to plot this two plots in a single plot. 
#Different class points will have different color [Setosa = Red, Versicolor = Green, Virginica = Blue]

sepal_length = df['sepal_length']
sepal_width = df['sepal_width']

plt.xlabel("sepal_length")
plt.ylabel("sepal_width")
plt.scatter(x = sepal_length, y = sepal_width)

plt.show()


petal_length = df['petal_length']
petal_width = df['petal_width']

plt.xlabel("petal_length")
plt.ylabel("petal_width")
plt.scatter(x = petal_length, y = petal_width,color="green")

plt.show()

# %%
#Task 5: Add a new column to the end of the dataframe, called 'Calyx Width'.
#If the flower's Sepal_length is < 5, 'Calyx Width' value will be 0, otherwise the value 

df['Calyx Width']=np.where(df['sepal_length']<5,0,1)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  Calyx Width
# 0           5.1          3.5           1.4          0.2  setosa            1
# 1           4.9          3.0           1.4          0.2  setosa            0
# 2           4.7          3.2           1.3          0.2  setosa            0
# 3           4.6          3.1           1.5          0.2  setosa            0
# 4           5.0          3.6           1.4          0.2  setosa            1

# %%
#Task 5: plot the Histogram of 'Sepal Length' column. 

sepal_length = df['sepal_length']
plt.hist(sepal_length,bins=[0,5,10,15,20])
plt.title('Histogram of Sepal Length ')
plt.show()
